# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold # import k-fold validation
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

import warnings

warnings.filterwarnings('ignore')

target_names = ['Class-0', 'Class-1', 'Class-2']

# %%
df = pd.read_csv('../processeddata/new_airlines_normalized.csv')
df.head(2)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003             0.301513
# 1           6            June       2003             0.088067
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                   0.270412                              0.350472
# 1                   0.093018                              0.069295
#
#    # of Delays.Security  ...  Flights.Total Minutes Delayed.Carrier  \
# 0              0.189474  ...       0.770892                0.258823
# 1              0.042105  ...       0.199003                0.066594
#
#    Minutes Delayed.Late Aircraft  Minutes Delayed.National Aviation System  \
# 0                       0.185741                                  0.194317
# 1                       0.067780                                  0.037010
#
#    Minutes Delayed.Security  Minutes Delayed.Total  Minutes Delayed.Weather  \
# 0                  0.104668               0.260628                 0.253219
# 1                  0.020004               0.064041                 0.053621
#
#    Time.Month.level      Rate  Ratio_Rank
# 0               3.0  0.797538         2.0
# 1               3.0  0.816993         1.0
#
# [2 rows x 27 columns]

# %%
col = ['# of Delays.Carrier',
       '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
       '# of Delays.Security', '# of Delays.Weather',
       'Flights.Cancelled',
       'Flights.Delayed', 'Flights.Diverted', #'Flights.On Time',
       'Flights.Total', 'Minutes Delayed.Carrier',
       'Minutes Delayed.Late Aircraft',
       'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
       'Minutes Delayed.Total', 'Minutes Delayed.Weather']

# %%
normalizedData = df[col]
normalizedData.shape
# Out:
# (4408, 15)

# %%
X = normalizedData.iloc[ :, :-1]
print(X.shape)
X.head()
# Out:
# (4408, 14)
#    # of Delays.Carrier  # of Delays.Late Aircraft  \
# 0             0.301513                   0.270412
# 1             0.088067                   0.093018
# 2             0.061849                   0.088924
# 3             0.063193                   0.087787
# 4             0.057479                   0.041392
#
#    # of Delays.National Aviation System  # of Delays.Security  \
# 0                              0.350472              0.189474
# 1                              0.069295              0.042105
# 2                              0.036424              0.094737
# 3                              0.074847              0.031579
# 4                              0.047307              0.052632
#
#    # of Delays.Weather  Flights.Cancelled  Flights.Delayed  Flights.Diverted  \
# 0             0.403206           0.057928         0.414431          0.061086
# 1             0.080148           0.036715         0.099881          0.006787
# 2             0.094945           0.007071         0.071705          0.033937
# 3             0.065351           0.019037         0.095334          0.031674
# 4             0.070284           0.019309         0.060897          0.040724
#
#    Flights.Total  Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0       0.770892                 0.258823                       0.185741
# 1       0.199003                 0.066594                       0.067780
# 2       0.161140                 0.035474                       0.063728
# 3       0.171866                 0.040725                       0.053647
# 4       0.111460                 0.036125                       0.025243
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                  0.194317                  0.104668
# 1                                  0.037010                  0.020004
# 2                                  0.025609                  0.056173
# 3                                  0.036017                  0.025662
# 4                                  0.031345                  0.024247
#
#    Minutes Delayed.Total
# 0               0.260628
# 1               0.064041
# 2               0.051023
# 3               0.052444
# 4               0.038985

# %%
y = df.iloc[ :, -1:]
y.head()
# Out:
#    Ratio_Rank
# 0         2.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0

# %%
X = X.to_numpy()
print(type(X))

y = y.to_numpy()
print(type(y))
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>

# %%
t = [x/10 for x in range(1, 9)]

knn = KNeighborsClassifier(n_neighbors = 5)

plt.figure()

for s in t:

    train_score = []
    test_score = []
    for i in range(1,100):
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1-s)
        knn.fit(X_train, y_train)
        train_score.append(knn.score(X_train, y_train))
        test_score.append(knn.score(X_test, y_test))
    plt.plot(s, np.mean(train_score), 'rx')
    plt.plot(s, np.mean(test_score), 'bo')
    plt.legend(['train_score', 'test_score'], loc='best')
    plt.title("KNN") 

plt.xlabel('Training set proportion (%)')
plt.ylabel('accuracy');

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
k_range = range(1, 100)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    scores.append(knn.score(X_test, y_test))

plt.figure()
plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.xticks([0, 25, 50, 75, 100]);
#plt.yticks([0.8,.85,0.9,.95,1]);
plt.title("KNN n_neighbors")
# Out:
# Text(0.5, 1.0, 'KNN n_neighbors')

# %%
k_value = [1, 5, 10, 15, 50]         # k = 10,15

for k in k_value:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    print(f"k={k}")
    
    # plot a confusion matrix
    confusion_mat = confusion_matrix(y_test, y_pred)
    print(confusion_mat)
    
    # Print classification report
   
    #classification_report(y_test, y_pred, target_names=target_names, output_dict=True)
    result_metrics = classification_report(y_test, y_pred, target_names=target_names)
    print(result_metrics)
# Out:
# k=1
# [[514  41   0]
#  [ 73 481  28]
#  [  0  44 142]]
#               precision    recall  f1-score   support
#
#      Class-0       0.88      0.93      0.90       555
#      Class-1       0.85      0.83      0.84       582
#      Class-2       0.84      0.76      0.80       186
#
#     accuracy                           0.86      1323
#    macro avg       0.85      0.84      0.85      1323
# weighted avg       0.86      0.86      0.86      1323
#
# k=5
# [[522  33   0]
#  [ 67 503  12]
#  [  0  49 137]]
#               precision    recall  f1-score   support
#
#      Class-0       0.89      0.94      0.91       555
#      Class-1       0.86      0.86      0.86       582
#      Class-2       0.92      0.74      0.82       186
#
#     accuracy                           0.88      1323
#    macro avg       0.89      0.85      0.86      1323
# weighted avg       0.88      0.88      0.88      1323
#
# k=10
# [[530  25   0]
#  [ 68 506   8]
#  [  0  62 124]]
#               precision    recall  f1-score   support
#
#      Class-0       0.89      0.95      0.92       555
#      Class-1       0.85      0.87      0.86       582
#      Class-2       0.94      0.67      0.78       186
#
#     accuracy                           0.88      1323
#    macro avg       0.89      0.83      0.85      1323
# weighted avg       0.88      0.88      0.87      1323
#
# k=15
# [[519  36   0]
#  [ 52 522   8]
#  [  0  61 125]]
#               precision    recall  f1-score   support
#
#      Class-0       0.91      0.94      0.92       555
#      Class-1       0.84      0.90      0.87       582
#      Class-2       0.94      0.67      0.78       186
#
#     accuracy                           0.88      1323
#    macro avg       0.90      0.83      0.86      1323
# weighted avg       0.88      0.88      0.88      1323
#
# k=50
# [[533  22   0]
#  [ 56 519   7]
#  [  0  92  94]]
#               precision    recall  f1-score   support
#
#      Class-0       0.90      0.96      0.93       555
#      Class-1       0.82      0.89      0.85       582
#      Class-2       0.93      0.51      0.66       186
#
#     accuracy                           0.87      1323
#    macro avg       0.89      0.79      0.81      1323
# weighted avg       0.87      0.87      0.86      1323

# %%
modelName = "KNN"
knn = KNeighborsClassifier(n_neighbors = 15).fit(X_train, y_train)

# %%
kf = KFold(n_splits=10, random_state=None, shuffle=True) # Define the split - into k folds 


c0_precisions = []
c0_recalls = []
c1_precisions = []
c1_recalls = []
accTotal = 0
n = 1
for train_index, test_index in kf.split(X):

    print("=========================Kfold" , n , "=======================")

    X_train, y_train = X[train_index], y[train_index]
    X_test, y_test = X[test_index], y[test_index]

    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)

    print(confusion_matrix(y_test, y_pred))

    # Get a dictionary of performance results and access the results
    results = classification_report(y_test, y_pred, target_names=target_names)
    print(results)


    metrics_dict = classification_report(y_test, y_pred, 
                        target_names=target_names, output_dict=True)

    #print(metrics_dict)

    print('precision (weighted):', metrics_dict['weighted avg']['precision'])
    print('recall avg (weighted):', metrics_dict['weighted avg']['recall'])
    accTotal = accTotal + metrics_dict['accuracy']
    print('accuracy: ', metrics_dict['accuracy'])

    n = n + 1
#print(accTotal/KFoldNum)
print('Accuracy of classifier: {:.2f}'.format((accTotal/10)))
# Out:
# =========================Kfold 1 =======================
# [[189  10   0]
#  [ 16 164   1]
#  [  0  17  44]]
#               precision    recall  f1-score   support
#
#      Class-0       0.92      0.95      0.94       199
#      Class-1       0.86      0.91      0.88       181
#      Class-2       0.98      0.72      0.83        61
#
#     accuracy                           0.90       441
#    macro avg       0.92      0.86      0.88       441
# weighted avg       0.90      0.90      0.90       441
#
# precision (weighted): 0.9036878677841639
# recall avg (weighted): 0.9002267573696145
# accuracy:  0.9002267573696145
# =========================Kfold 2 =======================
# [[179   7   0]
#  [ 17 177   6]
#  [  0  18  37]]
#               precision    recall  f1-score   support
#
#      Class-0       0.91      0.96      0.94       186
#      Class-1       0.88      0.89      0.88       200
#      Class-2       0.86      0.67      0.76        55
#
#     accuracy                           0.89       441
#    macro avg       0.88      0.84      0.86       441
# weighted avg       0.89      0.89      0.89       441
#
# precision (weighted): 0.889887648722448
# recall avg (weighted): 0.891156462585034
# accuracy:  0.891156462585034
# =========================Kfold 3 =======================
# [[192  16   0]
#  [ 13 153   4]
#  [  0  21  42]]
#               precision    recall  f1-score   support
#
#      Class-0       0.94      0.92      0.93       208
#      Class-1       0.81      0.90      0.85       170
#      Class-2       0.91      0.67      0.77        63
#
#     accuracy                           0.88       441
#    macro avg       0.88      0.83      0.85       441
# weighted avg       0.88      0.88      0.88       441
#
# precision (weighted): 0.8825991656918389
# recall avg (weighted): 0.8775510204081632
# accuracy:  0.8775510204081632
# =========================Kfold 4 =======================
# [[182   6   0]
#  [ 13 180   3]
#  [  0  19  38]]
#               precision    recall  f1-score   support
#
#      Class-0       0.93      0.97      0.95       188
#      Class-1       0.88      0.92      0.90       196
#      Class-2       0.93      0.67      0.78        57
#
#     accuracy                           0.91       441
#    macro avg       0.91      0.85      0.87       441
# weighted avg       0.91      0.91      0.90       441
#
# precision (weighted): 0.9079217594897037
# recall avg (weighted): 0.9070294784580499
# accuracy:  0.9070294784580499
# =========================Kfold 5 =======================
# [[187  15   0]
#  [ 10 169   8]
#  [  0  16  36]]
#               precision    recall  f1-score   support
#
#      Class-0       0.95      0.93      0.94       202
#      Class-1       0.84      0.90      0.87       187
#      Class-2       0.82      0.69      0.75        52
#
#     accuracy                           0.89       441
#    macro avg       0.87      0.84      0.85       441
# weighted avg       0.89      0.89      0.89       441
#
# precision (weighted): 0.8895842345552281
# recall avg (weighted): 0.8888888888888888
# accuracy:  0.8888888888888888
# =========================Kfold 6 =======================
# [[194  19   0]
#  [  7 164   4]
#  [  0  14  39]]
#               precision    recall  f1-score   support
#
#      Class-0       0.97      0.91      0.94       213
#      Class-1       0.83      0.94      0.88       175
#      Class-2       0.91      0.74      0.81        53
#
#     accuracy                           0.90       441
#    macro avg       0.90      0.86      0.88       441
# weighted avg       0.91      0.90      0.90       441
#
# precision (weighted): 0.9055263859000375
# recall avg (weighted): 0.9002267573696145
# accuracy:  0.9002267573696145
# =========================Kfold 7 =======================
# [[175  12   0]
#  [ 19 177   3]
#  [  0  16  39]]
#               precision    recall  f1-score   support
#
#      Class-0       0.90      0.94      0.92       187
#      Class-1       0.86      0.89      0.88       199
#      Class-2       0.93      0.71      0.80        55
#
#     accuracy                           0.89       441
#    macro avg       0.90      0.84      0.87       441
# weighted avg       0.89      0.89      0.89       441
#
# precision (weighted): 0.8879285890631741
# recall avg (weighted): 0.8866213151927438
# accuracy:  0.8866213151927438
# =========================Kfold 8 =======================
# [[177  11   0]
#  [  9 184   3]
#  [  0  19  38]]
#               precision    recall  f1-score   support
#
#      Class-0       0.95      0.94      0.95       188
#      Class-1       0.86      0.94      0.90       196
#      Class-2       0.93      0.67      0.78        57
#
#     accuracy                           0.90       441
#    macro avg       0.91      0.85      0.87       441
# weighted avg       0.91      0.90      0.90       441
#
# precision (weighted): 0.9076096566555915
# recall avg (weighted): 0.9047619047619048
# accuracy:  0.9047619047619048
# =========================Kfold 9 =======================
# [[184   7   1]
#  [ 14 153   3]
#  [  0  35  43]]
#               precision    recall  f1-score   support
#
#      Class-0       0.93      0.96      0.94       192
#      Class-1       0.78      0.90      0.84       170
#      Class-2       0.91      0.55      0.69        78
#
#     accuracy                           0.86       440
#    macro avg       0.88      0.80      0.82       440
# weighted avg       0.87      0.86      0.86       440
#
# precision (weighted): 0.8708421816739031
# recall avg (weighted): 0.8636363636363636
# accuracy:  0.8636363636363636
# =========================Kfold 10 =======================
# [[176  10   0]
#  [ 15 171   1]
#  [  0  22  45]]
#               precision    recall  f1-score   support
#
#      Class-0       0.92      0.95      0.93       186
#      Class-1       0.84      0.91      0.88       187
#      Class-2       0.98      0.67      0.80        67
#
#     accuracy                           0.89       440
#    macro avg       0.91      0.84      0.87       440
# weighted avg       0.90      0.89      0.89       440
#
# precision (weighted): 0.896496172512778
# recall avg (weighted): 0.8909090909090909
# accuracy:  0.8909090909090909
# Accuracy of classifier: 0.89
