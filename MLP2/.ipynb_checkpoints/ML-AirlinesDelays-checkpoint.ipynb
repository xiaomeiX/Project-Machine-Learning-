# %% [markdown]
# ### MLP2: Data Preprocessing and Exploratory Analysis

# %% [markdown]
# #### Write your name
#
# - xiaomei Xie
# - Lili Hao

# %% [markdown]
# #### Overview:  This dataset is all about flights in the united states, including information about the number, length, and type of delays. The data is reported for individual months at every major airport for every carrier.

# %% [markdown]
# ### (a) Datasets (10 pts)

# %%
# To plot pretty figures directly within Jupyter
# %matplotlib inline
import matplotlib as mpl

# Code example of load the data and prepared the data
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.linear_model


mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import os
datapath = os.path.join("../rawdata","")  
datapath
# Out:
# '../rawdata\\'

# %% [markdown]
# #### Load the data into a DataFrame

# %%
# Load the data
df = pd.read_csv(datapath + "airlines.csv", thousands=',')
df.shape
# Out:
# (4408, 24)

# %%
df.head(5)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  Statistics.# of Delays.Carrier  \
# 0           6            June       2003                            1009
# 1           6            June       2003                             374
# 2           6            June       2003                             296
# 3           6            June       2003                             300
# 4           6            June       2003                             283
#
#    Statistics.# of Delays.Late Aircraft  \
# 0                                  1275
# 1                                   495
# 2                                   477
# 3                                   472
# 4                                   268
#
#    Statistics.# of Delays.National Aviation System  \
# 0                                             3217
# 1                                              685
# 2                                              389
# 3                                              735
# 4                                              487
#
#    Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 0                               17  ...                        5843
# 1                                3  ...                        1623
# 2                                8  ...                        1245
# 3                                2  ...                        1562
# 4                                4  ...                        1100
#
#   Statistics.Flights.Diverted  Statistics.Flights.On Time  \
# 0                          27                       23974
# 1                           3                        7875
# 2                          15                        6998
# 3                          14                        7021
# 4                          18                        5321
#
#    Statistics.Flights.Total  Statistics.Minutes Delayed.Carrier  \
# 0                     30060                               61606
# 1                      9639                               20319
# 2                      8287                               13635
# 3                      8670                               14763
# 4                      6513                               13775
#
#    Statistics.Minutes Delayed.Late Aircraft  \
# 0                                     68335
# 1                                     28189
# 2                                     26810
# 3                                     23379
# 4                                     13712
#
#    Statistics.Minutes Delayed.National Aviation System  \
# 0                                             118831
# 1                                              24400
# 2                                              17556
# 3                                              23804
# 4                                              20999
#
#    Statistics.Minutes Delayed.Security  Statistics.Minutes Delayed.Total  \
# 0                                  518                            268764
# 1                                   99                             77167
# 2                                  278                             64480
# 3                                  127                             65865
# 4                                  120                             52747
#
#    Statistics.Minutes Delayed.Weather
# 0                               19474
# 1                                4160
# 2                                6201
# 3                                3792
# 4                                4141
#
# [5 rows x 24 columns]

# %%
df.tail(5)
# Out:
#      Airport.Code                                      Airport.Name  \
# 4403          SAN            San Diego, CA: San Diego International
# 4404          SEA         Seattle, WA: Seattle/Tacoma International
# 4405          SFO    San Francisco, CA: San Francisco International
# 4406          SLC  Salt Lake City, UT: Salt Lake City International
# 4407          TPA                    Tampa, FL: Tampa International
#
#      Time.Label  Time.Month Time.Month Name  Time.Year  \
# 4403    2016/01           1         January       2016
# 4404    2016/01           1         January       2016
# 4405    2016/01           1         January       2016
# 4406    2016/01           1         January       2016
# 4407    2016/01           1         January       2016
#
#       Statistics.# of Delays.Carrier  Statistics.# of Delays.Late Aircraft  \
# 4403                             280                                   397
# 4404                             357                                   513
# 4405                             560                                   947
# 4406                             338                                   540
# 4407                             410                                   342
#
#       Statistics.# of Delays.National Aviation System  \
# 4403                                              171
# 4404                                              351
# 4405                                             2194
# 4406                                              253
# 4407                                              312
#
#       Statistics.# of Delays.Security  ...  Statistics.Flights.Delayed  \
# 4403                                2  ...                         871
# 4404                                2  ...                        1274
# 4405                                2  ...                        3825
# 4406                                3  ...                        1175
# 4407                                2  ...                        1095
#
#      Statistics.Flights.Diverted  Statistics.Flights.On Time  \
# 4403                          18                        5030
# 4404                          31                        8330
# 4405                          20                        8912
# 4406                          14                        7426
# 4407                           7                        4748
#
#       Statistics.Flights.Total  Statistics.Minutes Delayed.Carrier  \
# 4403                      6016                               15482
# 4404                      9739                               25461
# 4405                     13206                               43641
# 4406                      8699                               32066
# 4407                      5996                               22557
#
#       Statistics.Minutes Delayed.Late Aircraft  \
# 4403                                     23023
# 4404                                     32693
# 4405                                     72557
# 4406                                     33682
# 4407                                     21164
#
#       Statistics.Minutes Delayed.National Aviation System  \
# 4403                                               6021
# 4404                                              11466
# 4405                                             153416
# 4406                                               8057
# 4407                                              11423
#
#       Statistics.Minutes Delayed.Security  Statistics.Minutes Delayed.Total  \
# 4403                                   79                             46206
# 4404                                   73                             74017
# 4405                                   66                            278610
# 4406                                   57                             76978
# 4407                                   37                             57774
#
#       Statistics.Minutes Delayed.Weather
# 4403                                1601
# 4404                                4324
# 4405                                8930
# 4406                                3116
# 4407                                2593
#
# [5 rows x 24 columns]

# %%
columns = df.columns
columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', 'Statistics.# of Delays.Carrier',
#        'Statistics.# of Delays.Late Aircraft',
#        'Statistics.# of Delays.National Aviation System',
#        'Statistics.# of Delays.Security', 'Statistics.# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Statistics.Carriers.Total',
#        'Statistics.Flights.Cancelled', 'Statistics.Flights.Delayed',
#        'Statistics.Flights.Diverted', 'Statistics.Flights.On Time',
#        'Statistics.Flights.Total', 'Statistics.Minutes Delayed.Carrier',
#        'Statistics.Minutes Delayed.Late Aircraft',
#        'Statistics.Minutes Delayed.National Aviation System',
#        'Statistics.Minutes Delayed.Security',
#        'Statistics.Minutes Delayed.Total',
#        'Statistics.Minutes Delayed.Weather'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4408 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Airport.Code                                         4408 non-null   object
#  1   Airport.Name                                         4408 non-null   object
#  2   Time.Label                                           4408 non-null   object
#  3   Time.Month                                           4408 non-null   int64
#  4   Time.Month Name                                      4408 non-null   object
#  5   Time.Year                                            4408 non-null   int64
#  6   Statistics.# of Delays.Carrier                       4408 non-null   int64
#  7   Statistics.# of Delays.Late Aircraft                 4408 non-null   int64
#  8   Statistics.# of Delays.National Aviation System      4408 non-null   int64
#  9   Statistics.# of Delays.Security                      4408 non-null   int64
#  10  Statistics.# of Delays.Weather                       4408 non-null   int64
#  11  Statistics.Carriers.Names                            4408 non-null   object
#  12  Statistics.Carriers.Total                            4408 non-null   int64
#  13  Statistics.Flights.Cancelled                         4408 non-null   int64
#  14  Statistics.Flights.Delayed                           4408 non-null   int64
#  15  Statistics.Flights.Diverted                          4408 non-null   int64
#  16  Statistics.Flights.On Time                           4408 non-null   int64
#  17  Statistics.Flights.Total                             4408 non-null   int64
#  18  Statistics.Minutes Delayed.Carrier                   4408 non-null   int64
#  19  Statistics.Minutes Delayed.Late Aircraft             4408 non-null   int64
#  20  Statistics.Minutes Delayed.National Aviation System  4408 non-null   int64
#  21  Statistics.Minutes Delayed.Security                  4408 non-null   int64
#  22  Statistics.Minutes Delayed.Total                     4408 non-null   int64
#  23  Statistics.Minutes Delayed.Weather                   4408 non-null   int64
# dtypes: int64(19), object(5)
# memory usage: 826.6+ KB

# %%
df.describe()
# Out:
#         Time.Month    Time.Year  Statistics.# of Delays.Carrier  \
# count  4408.000000  4408.000000                     4408.000000
# mean      6.578947  2009.243421                      574.632486
# std       3.457890     3.667475                      329.616475
# min       1.000000  2003.000000                      112.000000
# 25%       4.000000  2006.000000                      358.000000
# 50%       7.000000  2009.000000                      476.000000
# 75%      10.000000  2012.000000                      692.000000
# max      12.000000  2016.000000                     3087.000000
#
#        Statistics.# of Delays.Late Aircraft  \
# count                           4408.000000
# mean                             789.078947
# std                              561.798420
# min                               86.000000
# 25%                              425.000000
# 50%                              618.500000
# 75%                              959.000000
# max                             4483.000000
#
#        Statistics.# of Delays.National Aviation System  \
# count                                      4408.000000
# mean                                        954.580309
# std                                         921.907801
# min                                          61.000000
# 25%                                         399.000000
# 50%                                         667.500000
# 75%                                        1166.000000
# max                                        9066.000000
#
#        Statistics.# of Delays.Security  Statistics.# of Delays.Weather  \
# count                      4408.000000                     4408.000000
# mean                          5.575544                       78.216878
# std                           6.007046                       75.181726
# min                          -1.000000                        1.000000
# 25%                           2.000000                       33.000000
# 50%                           4.000000                       58.000000
# 75%                           7.000000                       98.000000
# max                          94.000000                      812.000000
#
#        Statistics.Carriers.Total  Statistics.Flights.Cancelled  \
# count                4408.000000                   4408.000000
# mean                   12.253403                    213.558076
# std                     2.289861                    288.873477
# min                     3.000000                      3.000000
# 25%                    11.000000                     58.000000
# 50%                    12.000000                    123.000000
# 75%                    14.000000                    250.000000
# max                    18.000000                   3680.000000
#
#        Statistics.Flights.Delayed  Statistics.Flights.Diverted  \
# count                 4408.000000                  4408.000000
# mean                  2402.000454                    27.880898
# std                   1710.947613                    36.356399
# min                    283.000000                     0.000000
# 25%                   1298.750000                     8.000000
# 50%                   1899.000000                    15.000000
# 75%                   2950.000000                    32.000000
# max                  13699.000000                   442.000000
#
#        Statistics.Flights.On Time  Statistics.Flights.Total  \
# count                 4408.000000               4408.000000
# mean                  9254.420826              11897.860254
# std                   5337.214211               6861.691876
# min                   2003.000000               2533.000000
# 25%                   5708.750000               7400.000000
# 50%                   7477.000000               9739.500000
# 75%                  10991.500000              13842.500000
# max                  31468.000000              38241.000000
#
#        Statistics.Minutes Delayed.Carrier  \
# count                         4408.000000
# mean                         35021.369782
# std                          24327.721037
# min                           6016.000000
# 25%                          19530.750000
# 50%                          27782.000000
# 75%                          41606.000000
# max                         220796.000000
#
#        Statistics.Minutes Delayed.Late Aircraft  \
# count                               4408.000000
# mean                               49410.274955
# std                                38750.017050
# min                                 5121.000000
# 25%                                25084.250000
# 50%                                37483.000000
# 75%                                59951.250000
# max                               345456.000000
#
#        Statistics.Minutes Delayed.National Aviation System  \
# count                                        4408.000000
# mean                                        45077.107985
# std                                         57636.745683
# min                                          2183.000000
# 25%                                         14389.000000
# 50%                                         25762.000000
# 75%                                         50362.000000
# max                                        602479.000000
#
#        Statistics.Minutes Delayed.Security  Statistics.Minutes Delayed.Total  \
# count                          4408.000000                       4408.000000
# mean                            211.769737                     135997.535163
# std                             257.174789                     113972.276370
# min                               0.000000                      14752.000000
# 25%                              65.000000                      65444.750000
# 50%                             141.000000                     100711.000000
# 75%                             274.000000                     164294.750000
# max                            4949.000000                     989367.000000
#
#        Statistics.Minutes Delayed.Weather
# count                         4408.000000
# mean                          6276.982759
# std                           6477.417169
# min                             46.000000
# 25%                           2310.750000
# 50%                           4298.500000
# 75%                           7846.000000
# max                          76770.000000

# %% [markdown]
# ### (b) Data preprocessing (10 pts)

# %% [markdown]
# ##### rename columns for easier query

# %%
df.rename(columns = {'Statistics.# of Delays.Carrier':'# of Delays.Carrier',
                      'Statistics.# of Delays.Late Aircraft':'# of Delays.Late Aircraft',
                      'Statistics.# of Delays.National Aviation System':'# of Delays.National Aviation System',
                      'Statistics.# of Delays.Security':'# of Delays.Security',
                      'Statistics.# of Delays.Weather':'# of Delays.Weather',
                      'Statistics.Carriers.Total':'Carriers.Total',
                      'Statistics.Flights.Cancelled':'Flights.Cancelled',
                      'Statistics.Flights.Delayed':'Flights.Delayed',
                      'Statistics.Flights.Diverted':'Flights.Diverted',
                      'Statistics.Flights.On Time':'Flights.On Time',
                       'Statistics.Flights.Total':'Flights.Total',
                      'Statistics.Minutes Delayed.Carrier':'Minutes Delayed.Carrier',
                      'Statistics.Minutes Delayed.Late Aircraft':'Minutes Delayed.Late Aircraft',
                       'Statistics.Minutes Delayed.National Aviation System': 'Minutes Delayed.National Aviation System',
                      'Statistics.Minutes Delayed.Security':'Minutes Delayed.Security',
                      'Statistics.Minutes Delayed.Total':'Minutes Delayed.Total',
                       'Statistics.Minutes Delayed.Weather': 'Minutes Delayed.Weather'
                    }, inplace = True)

# %%
df.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', '# of Delays.Carrier',
#        '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
#        '# of Delays.Security', '# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Carriers.Total', 'Flights.Cancelled',
#        'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
#        'Flights.Total', 'Minutes Delayed.Carrier',
#        'Minutes Delayed.Late Aircraft',
#        'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
#        'Minutes Delayed.Total', 'Minutes Delayed.Weather'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Airport.Code                                0
# Airport.Name                                0
# Time.Label                                  0
# Time.Month                                  0
# Time.Month Name                             0
# Time.Year                                   0
# # of Delays.Carrier                         0
# # of Delays.Late Aircraft                   0
# # of Delays.National Aviation System        0
# # of Delays.Security                        0
# # of Delays.Weather                         0
# Statistics.Carriers.Names                   0
# Carriers.Total                              0
# Flights.Cancelled                           0
# Flights.Delayed                             0
# Flights.Diverted                            0
# Flights.On Time                             0
# Flights.Total                               0
# Minutes Delayed.Carrier                     0
# Minutes Delayed.Late Aircraft               0
# Minutes Delayed.National Aviation System    0
# Minutes Delayed.Security                    0
# Minutes Delayed.Total                       0
# Minutes Delayed.Weather                     0
# dtype: int64

# %%
import seaborn as sb
sb.set_style('whitegrid')
from collections import Counter

# %%
df.boxplot(column='Minutes Delayed.Carrier', by='Time.Year', figsize=(15,7))
# Out:
# <AxesSubplot:title={'center':'Minutes Delayed.Carrier'}, xlabel='Time.Year'>

# %%
df.boxplot(column=['Minutes Delayed.Carrier',
                   'Minutes Delayed.Late Aircraft',
                   'Minutes Delayed.National Aviation System',
                   'Minutes Delayed.Security',
                   'Minutes Delayed.Weather',
                   'Minutes Delayed.Total'], figsize=(15,7))
# Out:
# <AxesSubplot:>

# %%
col = ['# of Delays.Carrier',
       '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
       '# of Delays.Security', '# of Delays.Weather',
       'Carriers.Total', 'Flights.Cancelled',
       'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
       'Flights.Total', 'Minutes Delayed.Carrier',
       'Minutes Delayed.Late Aircraft',
       'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
       'Minutes Delayed.Total', 'Minutes Delayed.Weather']

# %%
df.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                 1009
# 1           6            June       2003                  374
# 2           6            June       2003                  296
# 3           6            June       2003                  300
# 4           6            June       2003                  283
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                       1275                                  3217
# 1                        495                                   685
# 2                        477                                   389
# 3                        472                                   735
# 4                        268                                   487
#
#    # of Delays.Security  ...  Flights.Delayed Flights.Diverted  \
# 0                    17  ...             5843               27
# 1                     3  ...             1623                3
# 2                     8  ...             1245               15
# 3                     2  ...             1562               14
# 4                     4  ...             1100               18
#
#    Flights.On Time  Flights.Total  Minutes Delayed.Carrier  \
# 0            23974          30060                    61606
# 1             7875           9639                    20319
# 2             6998           8287                    13635
# 3             7021           8670                    14763
# 4             5321           6513                    13775
#
#    Minutes Delayed.Late Aircraft  Minutes Delayed.National Aviation System  \
# 0                          68335                                    118831
# 1                          28189                                     24400
# 2                          26810                                     17556
# 3                          23379                                     23804
# 4                          13712                                     20999
#
#    Minutes Delayed.Security  Minutes Delayed.Total  Minutes Delayed.Weather
# 0                       518                 268764                    19474
# 1                        99                  77167                     4160
# 2                       278                  64480                     6201
# 3                       127                  65865                     3792
# 4                       120                  52747                     4141
#
# [5 rows x 24 columns]

# %%
from scipy import stats

def delletOutlier(dfBK, col):
    for attr in col:
        dfBK = dfBK[(np.abs(stats.zscore(dfBK[[attr]])) < 3)]
    return dfBK

# %%
dfBK = df.copy()
dfBK.head(2)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                 1009
# 1           6            June       2003                  374
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                       1275                                  3217
# 1                        495                                   685
#
#    # of Delays.Security  ...  Flights.Delayed Flights.Diverted  \
# 0                    17  ...             5843               27
# 1                     3  ...             1623                3
#
#    Flights.On Time  Flights.Total  Minutes Delayed.Carrier  \
# 0            23974          30060                    61606
# 1             7875           9639                    20319
#
#    Minutes Delayed.Late Aircraft  Minutes Delayed.National Aviation System  \
# 0                          68335                                    118831
# 1                          28189                                     24400
#
#    Minutes Delayed.Security  Minutes Delayed.Total  Minutes Delayed.Weather
# 0                       518                 268764                    19474
# 1                        99                  77167                     4160
#
# [2 rows x 24 columns]

# %%
dfBK = delletOutlier(dfBK, col)
dfBK.shape
# Out:
# (3367, 24)

# %%
dfBK.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3367 entries, 1 to 4407
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Airport.Code                              3367 non-null   object
#  1   Airport.Name                              3367 non-null   object
#  2   Time.Label                                3367 non-null   object
#  3   Time.Month                                3367 non-null   int64
#  4   Time.Month Name                           3367 non-null   object
#  5   Time.Year                                 3367 non-null   int64
#  6   # of Delays.Carrier                       3367 non-null   int64
#  7   # of Delays.Late Aircraft                 3367 non-null   int64
#  8   # of Delays.National Aviation System      3367 non-null   int64
#  9   # of Delays.Security                      3367 non-null   int64
#  10  # of Delays.Weather                       3367 non-null   int64
#  11  Statistics.Carriers.Names                 3367 non-null   object
#  12  Carriers.Total                            3367 non-null   int64
#  13  Flights.Cancelled                         3367 non-null   int64
#  14  Flights.Delayed                           3367 non-null   int64
#  15  Flights.Diverted                          3367 non-null   int64
#  16  Flights.On Time                           3367 non-null   int64
#  17  Flights.Total                             3367 non-null   int64
#  18  Minutes Delayed.Carrier                   3367 non-null   int64
#  19  Minutes Delayed.Late Aircraft             3367 non-null   int64
#  20  Minutes Delayed.National Aviation System  3367 non-null   int64
#  21  Minutes Delayed.Security                  3367 non-null   int64
#  22  Minutes Delayed.Total                     3367 non-null   int64
#  23  Minutes Delayed.Weather                   3367 non-null   int64
# dtypes: int64(19), object(5)
# memory usage: 657.6+ KB

# %%
carrier.boxplot(column=['Minutes Delayed.Carrier',
                        'Minutes Delayed.Late Aircraft',
                        'Minutes Delayed.National Aviation System',
                        'Minutes Delayed.Security',
                        'Minutes Delayed.Weather',
                        '# of Delays.Weather',
                        'Minutes Delayed.Late Aircraft'], figsize=(15,7))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## additional time trend for total flights and delayed flight
# * a yearly decreasing trend
# * a seasonality change

# %%
fig,ax0=plt.subplots(nrows=1)
ax0.bar(df['Time.Year'],df['Flights.Total'], color='blue', width = 0.25)
ax0.bar(df['Time.Year'] + 0.25,df['Flights.Delayed'], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4408 artists>

# %%
fig,ax0=plt.subplots(nrows=1)
ax0.bar(df['Time.Month'],df['Flights.Total'], color='blue', width = 0.25)
ax0.bar(df['Time.Month'] + 0.25,df['Flights.Delayed'], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4408 artists>

# %%
carrier.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4341 entries, 0 to 4407
# Data columns (total 24 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Airport.Code                              4341 non-null   object
#  1   Airport.Name                              4341 non-null   object
#  2   Time.Label                                4341 non-null   object
#  3   Time.Month                                4341 non-null   int64
#  4   Time.Month Name                           4341 non-null   object
#  5   Time.Year                                 4341 non-null   int64
#  6   # of Delays.Carrier                       4341 non-null   int64
#  7   # of Delays.Late Aircraft                 4341 non-null   int64
#  8   # of Delays.National Aviation System      4341 non-null   int64
#  9   # of Delays.Security                      4341 non-null   int64
#  10  # of Delays.Weather                       4341 non-null   int64
#  11  Statistics.Carriers.Names                 4341 non-null   object
#  12  Carriers.Total                            4341 non-null   int64
#  13  Flights.Cancelled                         4341 non-null   int64
#  14  Flights.Delayed                           4341 non-null   int64
#  15  Flights.Diverted                          4341 non-null   int64
#  16  Flights.On Time                           4341 non-null   int64
#  17  Flights.Total                             4341 non-null   int64
#  18  Minutes Delayed.Carrier                   4341 non-null   int64
#  19  Minutes Delayed.Late Aircraft             4341 non-null   int64
#  20  Minutes Delayed.National Aviation System  4341 non-null   int64
#  21  Minutes Delayed.Security                  4341 non-null   int64
#  22  Minutes Delayed.Total                     4341 non-null   int64
#  23  Minutes Delayed.Weather                   4341 non-null   int64
# dtypes: int64(19), object(5)
# memory usage: 847.9+ KB

# %%
df.shape
# Out:
# (4408, 24)

# %%
dfNormalize = df.copy()

# %%
col = ['# of Delays.Carrier',
       '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
       '# of Delays.Security', '# of Delays.Weather',
       'Carriers.Total', 'Flights.Cancelled',
       'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
       'Flights.Total', 'Minutes Delayed.Carrier',
       'Minutes Delayed.Late Aircraft',
       'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
       'Minutes Delayed.Total', 'Minutes Delayed.Weather']

# %%
import numpy as np
import pandas as pd
import datetime
from sklearn import preprocessing

# %%
min_max = preprocessing.MinMaxScaler()
scaled_df = min_max.fit_transform(dfNormalize[col].values)
final_df = pd.DataFrame(scaled_df, columns=col)

# %%
final_df.head(2)
# Out:
#    # of Delays.Carrier  # of Delays.Late Aircraft  \
# 0             0.301513                   0.270412
# 1             0.088067                   0.093018
#
#    # of Delays.National Aviation System  # of Delays.Security  \
# 0                              0.350472              0.189474
# 1                              0.069295              0.042105
#
#    # of Delays.Weather  Carriers.Total  Flights.Cancelled  Flights.Delayed  \
# 0             0.403206        0.533333           0.057928         0.414431
# 1             0.080148        0.733333           0.036715         0.099881
#
#    Flights.Diverted  Flights.On Time  Flights.Total  Minutes Delayed.Carrier  \
# 0          0.061086         0.745664       0.770892                 0.258823
# 1          0.006787         0.199287       0.199003                 0.066594
#
#    Minutes Delayed.Late Aircraft  Minutes Delayed.National Aviation System  \
# 0                       0.185741                                  0.194317
# 1                       0.067780                                  0.037010
#
#    Minutes Delayed.Security  Minutes Delayed.Total  Minutes Delayed.Weather
# 0                  0.104668               0.260628                 0.253219
# 1                  0.020004               0.064041                 0.053621

# %%
final_df.to_csv('../processeddata/new_airlines_Normalized.csv', index=False)

# %%
nomalDF = pd.read_csv('../processeddata/new_airlines_Normalized.csv')
nomalDF.head(2)
# Out:
#    # of Delays.Carrier  # of Delays.Late Aircraft  \
# 0             0.301513                   0.270412
# 1             0.088067                   0.093018
#
#    # of Delays.National Aviation System  # of Delays.Security  \
# 0                              0.350472              0.189474
# 1                              0.069295              0.042105
#
#    # of Delays.Weather  Carriers.Total  Flights.Cancelled  Flights.Delayed  \
# 0             0.403206        0.533333           0.057928         0.414431
# 1             0.080148        0.733333           0.036715         0.099881
#
#    Flights.Diverted  Flights.On Time  Flights.Total  Minutes Delayed.Carrier  \
# 0          0.061086         0.745664       0.770892                 0.258823
# 1          0.006787         0.199287       0.199003                 0.066594
#
#    Minutes Delayed.Late Aircraft  Minutes Delayed.National Aviation System  \
# 0                       0.185741                                  0.194317
# 1                       0.067780                                  0.037010
#
#    Minutes Delayed.Security  Minutes Delayed.Total  Minutes Delayed.Weather
# 0                  0.104668               0.260628                 0.253219
# 1                  0.020004               0.064041                 0.053621

# %%
df.hist(column='Flights.On Time', by='Time.Year', bins=50,  alpha=0.5, figsize=(15,7))
# Out:
# array([[<AxesSubplot:title={'center':'2003'}>,
#         <AxesSubplot:title={'center':'2004'}>,
#         <AxesSubplot:title={'center':'2005'}>,
#         <AxesSubplot:title={'center':'2006'}>],
#        [<AxesSubplot:title={'center':'2007'}>,
#         <AxesSubplot:title={'center':'2008'}>,
#         <AxesSubplot:title={'center':'2009'}>,
#         <AxesSubplot:title={'center':'2010'}>],
#        [<AxesSubplot:title={'center':'2011'}>,
#         <AxesSubplot:title={'center':'2012'}>,
#         <AxesSubplot:title={'center':'2013'}>,
#         <AxesSubplot:title={'center':'2014'}>],
#        [<AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# ### Classify and Set attribute for the dataset

# %%
df['Rate'] = (df['Flights.Delayed'] / df['Flights.Total'])
df.head(5)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                 1009
# 1           6            June       2003                  374
# 2           6            June       2003                  296
# 3           6            June       2003                  300
# 4           6            June       2003                  283
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                       1275                                  3217
# 1                        495                                   685
# 2                        477                                   389
# 3                        472                                   735
# 4                        268                                   487
#
#    # of Delays.Security  ...  Flights.Diverted Flights.On Time  Flights.Total  \
# 0                    17  ...                27           23974          30060
# 1                     3  ...                 3            7875           9639
# 2                     8  ...                15            6998           8287
# 3                     2  ...                14            7021           8670
# 4                     4  ...                18            5321           6513
#
#    Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0                    61606                          68335
# 1                    20319                          28189
# 2                    13635                          26810
# 3                    14763                          23379
# 4                    13775                          13712
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                    118831                       518
# 1                                     24400                        99
# 2                                     17556                       278
# 3                                     23804                       127
# 4                                     20999                       120
#
#    Minutes Delayed.Total  Minutes Delayed.Weather      Rate
# 0                 268764                    19474  0.194378
# 1                  77167                     4160  0.168378
# 2                  64480                     6201  0.150235
# 3                  65865                     3792  0.180161
# 4                  52747                     4141  0.168893
#
# [5 rows x 25 columns]

# %%
mean = df.Rate.mean()
mean
# Out:
# 0.2001368515526982

# %%
df = df.assign(Ratio_Rank = lambda x: x['Rate']>mean)
df.head(10)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
# 5          DEN                   Denver, CO: Denver International    2003/06
# 6          DFW  Dallas/Fort Worth, TX: Dallas/Fort Worth Inter...    2003/06
# 7          DTW            Detroit, MI: Detroit Metro Wayne County    2003/06
# 8          EWR           Newark, NJ: Newark Liberty International    2003/06
# 9          FLL  Fort Lauderdale, FL: Fort Lauderdale-Hollywood...    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                 1009
# 1           6            June       2003                  374
# 2           6            June       2003                  296
# 3           6            June       2003                  300
# 4           6            June       2003                  283
# 5           6            June       2003                  516
# 6           6            June       2003                  986
# 7           6            June       2003                  376
# 8           6            June       2003                  322
# 9           6            June       2003                  247
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                       1275                                  3217
# 1                        495                                   685
# 2                        477                                   389
# 3                        472                                   735
# 4                        268                                   487
# 5                        323                                   664
# 6                       1390                                  2147
# 7                        371                                   570
# 8                        519                                  1948
# 9                        256                                   427
#
#    # of Delays.Security  ...  Flights.On Time Flights.Total  \
# 0                    17  ...            23974         30060
# 1                     3  ...             7875          9639
# 2                     8  ...             6998          8287
# 3                     2  ...             7021          8670
# 4                     4  ...             5321          6513
# 5                    11  ...            10024         11691
# 6                    19  ...            22303         27628
# 7                     6  ...            10227         11754
# 8                    10  ...             9441         12506
# 9                     5  ...             3672          4662
#
#    Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0                    61606                          68335
# 1                    20319                          28189
# 2                    13635                          26810
# 3                    14763                          23379
# 4                    13775                          13712
# 5                    26634                          18969
# 6                    70918                          80714
# 7                    21802                          18715
# 8                    20190                          30905
# 9                    12547                          14600
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                    118831                       518
# 1                                     24400                        99
# 2                                     17556                       278
# 3                                     23804                       127
# 4                                     20999                       120
# 5                                     23538                       706
# 6                                     90574                       683
# 7                                     16482                       139
# 8                                     91048                       490
# 9                                     14935                       141
#
#    Minutes Delayed.Total  Minutes Delayed.Weather      Rate  Ratio_Rank
# 0                 268764                    19474  0.194378       False
# 1                  77167                     4160  0.168378       False
# 2                  64480                     6201  0.150235       False
# 3                  65865                     3792  0.180161       False
# 4                  52747                     4141  0.168893       False
# 5                  75428                     5581  0.137798       False
# 6                 263521                    20632  0.173664       False
# 7                  60667                     3529  0.118683       False
# 8                 150513                     7880  0.233568        True
# 9                  44303                     2080  0.207422        True
#
# [10 rows x 26 columns]

# %%
df.to_csv('../processeddata/new_airlines_Rank.csv', index=False)

# %% [markdown]
# ### (c) Exploratory data analysis (20 pts)

# %%
import matplotlib.pyplot as plt 
from pandas.plotting import scatter_matrix

# %%
col = ['# of Delays.Carrier',
       '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
       '# of Delays.Security', '# of Delays.Weather',
       'Statistics.Carriers.Names', 'Carriers.Total', 'Flights.Cancelled',
       'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
       'Flights.Total', 'Minutes Delayed.Carrier',
       'Minutes Delayed.Late Aircraft',
       'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
       'Minutes Delayed.Total', 'Minutes Delayed.Weather']

# %%
df.corr()
# Out:
#                                           Time.Month  Time.Year  \
# Time.Month                                  1.000000  -0.075977
# Time.Year                                  -0.075977   1.000000
# # of Delays.Carrier                        -0.008749  -0.067204
# # of Delays.Late Aircraft                  -0.021178   0.000373
# # of Delays.National Aviation System       -0.010177  -0.195279
# # of Delays.Security                        0.044398  -0.315334
# # of Delays.Weather                        -0.063141  -0.191346
# Carriers.Total                              0.009466  -0.483083
# Flights.Cancelled                          -0.132985  -0.046951
# Flights.Delayed                            -0.016750  -0.127542
# Flights.Diverted                           -0.009689  -0.005181
# Flights.On Time                             0.024357  -0.052625
# Flights.Total                               0.009119  -0.074740
# Minutes Delayed.Carrier                    -0.019420   0.028561
# Minutes Delayed.Late Aircraft              -0.027362   0.026476
# Minutes Delayed.National Aviation System   -0.008659  -0.150661
# Minutes Delayed.Security                    0.043901  -0.249772
# Minutes Delayed.Total                      -0.021451  -0.069273
# Minutes Delayed.Weather                    -0.065504  -0.134033
# Rate                                       -0.057584  -0.138565
# Ratio_Rank                                 -0.054722  -0.114675
#
#                                           # of Delays.Carrier  \
# Time.Month                                          -0.008749
# Time.Year                                           -0.067204
# # of Delays.Carrier                                  1.000000
# # of Delays.Late Aircraft                            0.872725
# # of Delays.National Aviation System                 0.648211
# # of Delays.Security                                 0.407397
# # of Delays.Weather                                  0.729619
# Carriers.Total                                       0.333489
# Flights.Cancelled                                    0.518305
# Flights.Delayed                                      0.861985
# Flights.Diverted                                     0.440189
# Flights.On Time                                      0.758744
# Flights.Total                                        0.829259
# Minutes Delayed.Carrier                              0.952155
# Minutes Delayed.Late Aircraft                        0.836543
# Minutes Delayed.National Aviation System             0.532933
# Minutes Delayed.Security                             0.380787
# Minutes Delayed.Total                                0.798300
# Minutes Delayed.Weather                              0.708586
# Rate                                                 0.322454
# Ratio_Rank                                           0.286063
#
#                                           # of Delays.Late Aircraft  \
# Time.Month                                                -0.021178
# Time.Year                                                  0.000373
# # of Delays.Carrier                                        0.872725
# # of Delays.Late Aircraft                                  1.000000
# # of Delays.National Aviation System                       0.703330
# # of Delays.Security                                       0.312898
# # of Delays.Weather                                        0.684675
# Carriers.Total                                             0.268856
# Flights.Cancelled                                          0.608284
# Flights.Delayed                                            0.906646
# Flights.Diverted                                           0.541561
# Flights.On Time                                            0.741917
# Flights.Total                                              0.831632
# Minutes Delayed.Carrier                                    0.894121
# Minutes Delayed.Late Aircraft                              0.979729
# Minutes Delayed.National Aviation System                   0.626905
# Minutes Delayed.Security                                   0.297629
# Minutes Delayed.Total                                      0.881326
# Minutes Delayed.Weather                                    0.697966
# Rate                                                       0.370247
# Ratio_Rank                                                 0.310253
#
#                                           # of Delays.National Aviation System  \
# Time.Month                                                           -0.010177
# Time.Year                                                            -0.195279
# # of Delays.Carrier                                                   0.648211
# # of Delays.Late Aircraft                                             0.703330
# # of Delays.National Aviation System                                  1.000000
# # of Delays.Security                                                  0.216732
# # of Delays.Weather                                                   0.731453
# Carriers.Total                                                        0.263649
# Flights.Cancelled                                                     0.655539
# Flights.Delayed                                                       0.927546
# Flights.Diverted                                                      0.485182
# Flights.On Time                                                       0.590919
# Flights.Total                                                         0.721083
# Minutes Delayed.Carrier                                               0.691461
# Minutes Delayed.Late Aircraft                                         0.730317
# Minutes Delayed.National Aviation System                              0.956954
# Minutes Delayed.Security                                              0.243707
# Minutes Delayed.Total                                                 0.920091
# Minutes Delayed.Weather                                               0.698585
# Rate                                                                  0.543915
# Ratio_Rank                                                            0.394428
#
#                                           # of Delays.Security  \
# Time.Month                                            0.044398
# Time.Year                                            -0.315334
# # of Delays.Carrier                                   0.407397
# # of Delays.Late Aircraft                             0.312898
# # of Delays.National Aviation System                  0.216732
# # of Delays.Security                                  1.000000
# # of Delays.Weather                                   0.278034
# Carriers.Total                                        0.235272
# Flights.Cancelled                                     0.117530
# Flights.Delayed                                       0.313698
# Flights.Diverted                                      0.132249
# Flights.On Time                                       0.258856
# Flights.Total                                         0.285214
# Minutes Delayed.Carrier                               0.297827
# Minutes Delayed.Late Aircraft                         0.263751
# Minutes Delayed.National Aviation System              0.148077
# Minutes Delayed.Security                              0.868281
# Minutes Delayed.Total                                 0.244291
# Minutes Delayed.Weather                               0.249887
# Rate                                                  0.171717
# Ratio_Rank                                            0.151651
#
#                                           # of Delays.Weather  Carriers.Total  \
# Time.Month                                          -0.063141        0.009466
# Time.Year                                           -0.191346       -0.483083
# # of Delays.Carrier                                  0.729619        0.333489
# # of Delays.Late Aircraft                            0.684675        0.268856
# # of Delays.National Aviation System                 0.731453        0.263649
# # of Delays.Security                                 0.278034        0.235272
# # of Delays.Weather                                  1.000000        0.234537
# Carriers.Total                                       0.234537        1.000000
# Flights.Cancelled                                    0.586373        0.160970
# Flights.Delayed                                      0.804410        0.305701
# Flights.Diverted                                     0.563340        0.074464
# Flights.On Time                                      0.556228        0.280551
# Flights.Total                                        0.660898        0.301617
# Minutes Delayed.Carrier                              0.755613        0.250009
# Minutes Delayed.Late Aircraft                        0.697096        0.223946
# Minutes Delayed.National Aviation System             0.659647        0.198423
# Minutes Delayed.Security                             0.280510        0.203467
# Minutes Delayed.Total                                0.787211        0.241707
# Minutes Delayed.Weather                              0.962323        0.200550
# Rate                                                 0.448343        0.157137
# Ratio_Rank                                           0.355282        0.121233
#
#                                           Flights.Cancelled  Flights.Delayed  \
# Time.Month                                        -0.132985        -0.016750
# Time.Year                                         -0.046951        -0.127542
# # of Delays.Carrier                                0.518305         0.861985
# # of Delays.Late Aircraft                          0.608284         0.906646
# # of Delays.National Aviation System               0.655539         0.927546
# # of Delays.Security                               0.117530         0.313698
# # of Delays.Weather                                0.586373         0.804410
# Carriers.Total                                     0.160970         0.305701
# Flights.Cancelled                                  1.000000         0.678981
# Flights.Delayed                                    0.678981         1.000000
# Flights.Diverted                                   0.428933         0.549239
# Flights.On Time                                    0.413247         0.733519
# Flights.Total                                      0.535110         0.851394
# Minutes Delayed.Carrier                            0.591412         0.883851
# Minutes Delayed.Late Aircraft                      0.656723         0.907936
# Minutes Delayed.National Aviation System           0.675313         0.853660
# Minutes Delayed.Security                           0.138741         0.317777
# Minutes Delayed.Total                              0.726973         0.974404
# Minutes Delayed.Weather                            0.626871         0.785264
# Rate                                               0.365201         0.497103
# Ratio_Rank                                         0.276560         0.385688
#
#                                           ...  Flights.On Time  Flights.Total  \
# Time.Month                                ...         0.024357       0.009119
# Time.Year                                 ...        -0.052625      -0.074740
# # of Delays.Carrier                       ...         0.758744       0.829259
# # of Delays.Late Aircraft                 ...         0.741917       0.831632
# # of Delays.National Aviation System      ...         0.590919       0.721083
# # of Delays.Security                      ...         0.258856       0.285214
# # of Delays.Weather                       ...         0.556228       0.660898
# Carriers.Total                            ...         0.280551       0.301617
# Flights.Cancelled                         ...         0.413247       0.535110
# Flights.Delayed                           ...         0.733519       0.851394
# Flights.Diverted                          ...         0.426534       0.492078
# Flights.On Time                           ...         1.000000       0.980386
# Flights.Total                             ...         0.980386       1.000000
# Minutes Delayed.Carrier                   ...         0.793701       0.865491
# Minutes Delayed.Late Aircraft             ...         0.679285       0.785499
# Minutes Delayed.National Aviation System  ...         0.459501       0.601323
# Minutes Delayed.Security                  ...         0.277683       0.301800
# Minutes Delayed.Total                     ...         0.663572       0.792889
# Minutes Delayed.Weather                   ...         0.531387       0.638822
# Rate                                      ...        -0.119242       0.047989
# Ratio_Rank                                ...        -0.093695       0.036051
#
#                                           Minutes Delayed.Carrier  \
# Time.Month                                              -0.019420
# Time.Year                                                0.028561
# # of Delays.Carrier                                      0.952155
# # of Delays.Late Aircraft                                0.894121
# # of Delays.National Aviation System                     0.691461
# # of Delays.Security                                     0.297827
# # of Delays.Weather                                      0.755613
# Carriers.Total                                           0.250009
# Flights.Cancelled                                        0.591412
# Flights.Delayed                                          0.883851
# Flights.Diverted                                         0.536772
# Flights.On Time                                          0.793701
# Flights.Total                                            0.865491
# Minutes Delayed.Carrier                                  1.000000
# Minutes Delayed.Late Aircraft                            0.884543
# Minutes Delayed.National Aviation System                 0.596586
# Minutes Delayed.Security                                 0.304070
# Minutes Delayed.Total                                    0.859861
# Minutes Delayed.Weather                                  0.761585
# Rate                                                     0.304897
# Ratio_Rank                                               0.263740
#
#                                           Minutes Delayed.Late Aircraft  \
# Time.Month                                                    -0.027362
# Time.Year                                                      0.026476
# # of Delays.Carrier                                            0.836543
# # of Delays.Late Aircraft                                      0.979729
# # of Delays.National Aviation System                           0.730317
# # of Delays.Security                                           0.263751
# # of Delays.Weather                                            0.697096
# Carriers.Total                                                 0.223946
# Flights.Cancelled                                              0.656723
# Flights.Delayed                                                0.907936
# Flights.Diverted                                               0.583749
# Flights.On Time                                                0.679285
# Flights.Total                                                  0.785499
# Minutes Delayed.Carrier                                        0.884543
# Minutes Delayed.Late Aircraft                                  1.000000
# Minutes Delayed.National Aviation System                       0.690135
# Minutes Delayed.Security                                       0.262286
# Minutes Delayed.Total                                          0.919721
# Minutes Delayed.Weather                                        0.727009
# Rate                                                           0.435758
# Ratio_Rank                                                     0.356558
#
#                                           Minutes Delayed.National Aviation System  \
# Time.Month                                                               -0.008659
# Time.Year                                                                -0.150661
# # of Delays.Carrier                                                       0.532933
# # of Delays.Late Aircraft                                                 0.626905
# # of Delays.National Aviation System                                      0.956954
# # of Delays.Security                                                      0.148077
# # of Delays.Weather                                                       0.659647
# Carriers.Total                                                            0.198423
# Flights.Cancelled                                                         0.675313
# Flights.Delayed                                                           0.853660
# Flights.Diverted                                                          0.494755
# Flights.On Time                                                           0.459501
# Flights.Total                                                             0.601323
# Minutes Delayed.Carrier                                                   0.596586
# Minutes Delayed.Late Aircraft                                             0.690135
# Minutes Delayed.National Aviation System                                  1.000000
# Minutes Delayed.Security                                                  0.184170
# Minutes Delayed.Total                                                     0.905290
# Minutes Delayed.Weather                                                   0.654201
# Rate                                                                      0.574809
# Ratio_Rank                                                                0.400640
#
#                                           Minutes Delayed.Security  \
# Time.Month                                                0.043901
# Time.Year                                                -0.249772
# # of Delays.Carrier                                       0.380787
# # of Delays.Late Aircraft                                 0.297629
# # of Delays.National Aviation System                      0.243707
# # of Delays.Security                                      0.868281
# # of Delays.Weather                                       0.280510
# Carriers.Total                                            0.203467
# Flights.Cancelled                                         0.138741
# Flights.Delayed                                           0.317777
# Flights.Diverted                                          0.138240
# Flights.On Time                                           0.277683
# Flights.Total                                             0.301800
# Minutes Delayed.Carrier                                   0.304070
# Minutes Delayed.Late Aircraft                             0.262286
# Minutes Delayed.National Aviation System                  0.184170
# Minutes Delayed.Security                                  1.000000
# Minutes Delayed.Total                                     0.263676
# Minutes Delayed.Weather                                   0.249901
# Rate                                                      0.146087
# Ratio_Rank                                                0.126493
#
#                                           Minutes Delayed.Total  \
# Time.Month                                            -0.021451
# Time.Year                                             -0.069273
# # of Delays.Carrier                                    0.798300
# # of Delays.Late Aircraft                              0.881326
# # of Delays.National Aviation System                   0.920091
# # of Delays.Security                                   0.244291
# # of Delays.Weather                                    0.787211
# Carriers.Total                                         0.241707
# Flights.Cancelled                                      0.726973
# Flights.Delayed                                        0.974404
# Flights.Diverted                                       0.598963
# Flights.On Time                                        0.663572
# Flights.Total                                          0.792889
# Minutes Delayed.Carrier                                0.859861
# Minutes Delayed.Late Aircraft                          0.919721
# Minutes Delayed.National Aviation System               0.905290
# Minutes Delayed.Security                               0.263676
# Minutes Delayed.Total                                  1.000000
# Minutes Delayed.Weather                                0.797974
# Rate                                                   0.529782
# Ratio_Rank                                             0.400967
#
#                                           Minutes Delayed.Weather      Rate  \
# Time.Month                                              -0.065504 -0.057584
# Time.Year                                               -0.134033 -0.138565
# # of Delays.Carrier                                      0.708586  0.322454
# # of Delays.Late Aircraft                                0.697966  0.370247
# # of Delays.National Aviation System                     0.698585  0.543915
# # of Delays.Security                                     0.249887  0.171717
# # of Delays.Weather                                      0.962323  0.448343
# Carriers.Total                                           0.200550  0.157137
# Flights.Cancelled                                        0.626871  0.365201
# Flights.Delayed                                          0.785264  0.497103
# Flights.Diverted                                         0.622907  0.266707
# Flights.On Time                                          0.531387 -0.119242
# Flights.Total                                            0.638822  0.047989
# Minutes Delayed.Carrier                                  0.761585  0.304897
# Minutes Delayed.Late Aircraft                            0.727009  0.435758
# Minutes Delayed.National Aviation System                 0.654201  0.574809
# Minutes Delayed.Security                                 0.249901  0.146087
# Minutes Delayed.Total                                    0.797974  0.529782
# Minutes Delayed.Weather                                  1.000000  0.449212
# Rate                                                     0.449212  1.000000
# Ratio_Rank                                               0.361596  0.793031
#
#                                           Ratio_Rank
# Time.Month                                 -0.054722
# Time.Year                                  -0.114675
# # of Delays.Carrier                         0.286063
# # of Delays.Late Aircraft                   0.310253
# # of Delays.National Aviation System        0.394428
# # of Delays.Security                        0.151651
# # of Delays.Weather                         0.355282
# Carriers.Total                              0.121233
# Flights.Cancelled                           0.276560
# Flights.Delayed                             0.385688
# Flights.Diverted                            0.210482
# Flights.On Time                            -0.093695
# Flights.Total                               0.036051
# Minutes Delayed.Carrier                     0.263740
# Minutes Delayed.Late Aircraft               0.356558
# Minutes Delayed.National Aviation System    0.400640
# Minutes Delayed.Security                    0.126493
# Minutes Delayed.Total                       0.400967
# Minutes Delayed.Weather                     0.361596
# Rate                                        0.793031
# Ratio_Rank                                  1.000000
#
# [21 rows x 21 columns]

# %%
# scatter matrix plot
scatter_matrix(df[col],alpha=0.2,figsize=(16,16))
plt.show()

# %%
# import required libraries 
import pandas as pd 
import seaborn as sb

# %%
fig, ax = plt.subplots(figsize=(16,16))
sb.heatmap(df.corr(method = 'spearman'),annot=True, linewidths=0.4,annot_kws={'size':10},ax=ax,cbar=True)
plt.xticks(rotation=30)
plt.show()

# %%
df.columns
# Out:
# Index(['Airport.Code', 'Airport.Name', 'Time.Label', 'Time.Month',
#        'Time.Month Name', 'Time.Year', '# of Delays.Carrier',
#        '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
#        '# of Delays.Security', '# of Delays.Weather',
#        'Statistics.Carriers.Names', 'Carriers.Total', 'Flights.Cancelled',
#        'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
#        'Flights.Total', 'Minutes Delayed.Carrier',
#        'Minutes Delayed.Late Aircraft',
#        'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
#        'Minutes Delayed.Total', 'Minutes Delayed.Weather', 'Rate',
#        'Ratio_Rank'],
#       dtype='object')

# %%
df.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                 1009
# 1           6            June       2003                  374
# 2           6            June       2003                  296
# 3           6            June       2003                  300
# 4           6            June       2003                  283
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                       1275                                  3217
# 1                        495                                   685
# 2                        477                                   389
# 3                        472                                   735
# 4                        268                                   487
#
#    # of Delays.Security  ...  Flights.On Time Flights.Total  \
# 0                    17  ...            23974         30060
# 1                     3  ...             7875          9639
# 2                     8  ...             6998          8287
# 3                     2  ...             7021          8670
# 4                     4  ...             5321          6513
#
#    Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0                    61606                          68335
# 1                    20319                          28189
# 2                    13635                          26810
# 3                    14763                          23379
# 4                    13775                          13712
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                    118831                       518
# 1                                     24400                        99
# 2                                     17556                       278
# 3                                     23804                       127
# 4                                     20999                       120
#
#    Minutes Delayed.Total  Minutes Delayed.Weather      Rate  Ratio_Rank
# 0                 268764                    19474  0.194378       False
# 1                  77167                     4160  0.168378       False
# 2                  64480                     6201  0.150235       False
# 3                  65865                     3792  0.180161       False
# 4                  52747                     4141  0.168893       False
#
# [5 rows x 26 columns]

# %%
col = ['# of Delays.Carrier',
       '# of Delays.Late Aircraft', '# of Delays.National Aviation System',
       '# of Delays.Security', '# of Delays.Weather',
       'Carriers.Total', 'Flights.Cancelled',
       'Flights.Delayed', 'Flights.Diverted', 'Flights.On Time',
       'Flights.Total', 'Minutes Delayed.Carrier',
       'Minutes Delayed.Late Aircraft',
       'Minutes Delayed.National Aviation System', 'Minutes Delayed.Security',
       'Minutes Delayed.Total', 'Minutes Delayed.Weather']

# %%
dfCopy = df.copy()

# %%
def getFiveNumber(dfCopy, attr):
    Q1 = dfCopy[attr].quantile(0.25)
    Q3 = dfCopy[attr].quantile(0.75)
    median =dfCopy[attr].median()
    return Q1, Q3, median

# %%
for attr in col:

    Q1, Q3, median = getFiveNumber(dfCopy, attr)
    
    dfCopy.loc[ dfCopy[attr] <= Q1, attr] = 0
    dfCopy.loc[(dfCopy[attr] > Q1) & (dfCopy[attr] <= median), attr] = 1
    dfCopy.loc[(dfCopy[attr] > median) & (dfCopy[attr] <= Q3), attr] = 2
    dfCopy.loc[(dfCopy[attr] > Q3), attr] = 3

# %%
dfCopy = dfCopy.drop(['Rate'], axis = 1)

# %%
dfCopy.head()
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
# 2          BWI  Baltimore, MD: Baltimore/Washington Internatio...    2003/06
# 3          CLT     Charlotte, NC: Charlotte Douglas International    2003/06
# 4          DCA  Washington, DC: Ronald Reagan Washington National    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                    3
# 1           6            June       2003                    1
# 2           6            June       2003                    0
# 3           6            June       2003                    0
# 4           6            June       2003                    0
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                          3                                     3
# 1                          1                                     2
# 2                          1                                     0
# 3                          1                                     2
# 4                          0                                     1
#
#    # of Delays.Security  ...  Flights.Diverted Flights.On Time  Flights.Total  \
# 0                     3  ...                 2               3              3
# 1                     1  ...                 0               2              1
# 2                     3  ...                 1               1              1
# 3                     0  ...                 1               1              1
# 4                     1  ...                 2               0              0
#
#    Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0                        3                              3
# 1                        1                              1
# 2                        0                              1
# 3                        0                              0
# 4                        0                              0
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                         3                         3
# 1                                         1                         1
# 2                                         1                         3
# 3                                         1                         1
# 4                                         1                         1
#
#    Minutes Delayed.Total  Minutes Delayed.Weather  Ratio_Rank
# 0                      3                        3       False
# 1                      1                        1       False
# 2                      0                        2       False
# 3                      1                        1       False
# 4                      0                        1       False
#
# [5 rows x 25 columns]

# %%
dfCopy.to_csv('../processeddata/new_airlines_EDA.csv', index=False)

# %%
opDF = pd.read_csv('../processeddata/new_airlines_EDA.csv')

# %%
opDF.head(2)
# Out:
#   Airport.Code                                       Airport.Name Time.Label  \
# 0          ATL  Atlanta, GA: Hartsfield-Jackson Atlanta Intern...    2003/06
# 1          BOS                    Boston, MA: Logan International    2003/06
#
#    Time.Month Time.Month Name  Time.Year  # of Delays.Carrier  \
# 0           6            June       2003                    3
# 1           6            June       2003                    1
#
#    # of Delays.Late Aircraft  # of Delays.National Aviation System  \
# 0                          3                                     3
# 1                          1                                     2
#
#    # of Delays.Security  ...  Flights.Diverted Flights.On Time  Flights.Total  \
# 0                     3  ...                 2               3              3
# 1                     1  ...                 0               2              1
#
#    Minutes Delayed.Carrier  Minutes Delayed.Late Aircraft  \
# 0                        3                              3
# 1                        1                              1
#
#    Minutes Delayed.National Aviation System  Minutes Delayed.Security  \
# 0                                         3                         3
# 1                                         1                         1
#
#    Minutes Delayed.Total  Minutes Delayed.Weather  Ratio_Rank
# 0                      3                        3       False
# 1                      1                        1       False
#
# [2 rows x 25 columns]
